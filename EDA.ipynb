# %%
import pandas as pd
from matplotlib import pyplot as plt
import numpy as np

# %%
vehicles = pd.read_csv('vehicles_us.csv')
vehicles.head()
# Out:
#    price  model_year           model  condition  cylinders fuel  odometer  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type paint_color  is_4wd date_posted  days_listed
# 0    automatic     SUV         NaN     1.0  2018-06-23           19
# 1    automatic  pickup       white     1.0  2018-10-19           50
# 2    automatic   sedan         red     NaN  2019-02-07           79
# 3    automatic  pickup         NaN     NaN  2019-03-22            9
# 4    automatic   sedan       black     NaN  2019-04-02           28

# %%
vehicles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 14852 entries, 5 to 51515
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         14852 non-null  int64
#  1   model_year    14852 non-null  float64
#  2   model         14852 non-null  object
#  3   condition     14852 non-null  object
#  4   cylinders     14852 non-null  float64
#  5   fuel          14852 non-null  object
#  6   odometer      14852 non-null  float64
#  7   transmission  14852 non-null  object
#  8   type          14852 non-null  object
#  9   paint_color   14852 non-null  object
#  10  is_4wd        14852 non-null  float64
#  11  date_posted   14852 non-null  object
#  12  days_listed   14852 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 1.6+ MB

# %%
display(vehicles.columns)
# Out:
# Index(['price', 'model_year', 'model', 'condition', 'cylinders', 'fuel',
#        'odometer', 'transmission', 'type', 'paint_color', 'is_4wd',
#        'date_posted', 'days_listed'],
#       dtype='object')

# %%
#Converting the columns of the vehicles to list to confirm that the names of the columns don't have extra spaces
display(vehicles.columns.tolist())
# Out:
# ['price',
#  'model_year',
#  'model',
#  'condition',
#  'cylinders',
#  'fuel',
#  'odometer',
#  'transmission',
#  'type',
#  'paint_color',
#  'is_4wd',
#  'date_posted',
#  'days_listed']

# %%
#Displaying a sample of data for vehicles
display(vehicles.sample())
# Out:
#        price  model_year                    model  condition  cylinders fuel  \
# 42029  24995      2013.0  jeep wrangler unlimited  excellent        6.0  gas
# 43880  18900      2015.0               ford f-150  excellent        8.0  gas
# 18958  19100      2012.0        cadillac escalade   like new        8.0  gas
# 1637   21362      2014.0               ford f-150  excellent        6.0  gas
# 1826    4500      1997.0               ford f-150       good        8.0  gas
# 4068   34899      2017.0            toyota tundra  excellent        8.0  gas
# 10352   5800      1999.0          chevrolet tahoe  excellent        8.0  gas
# 9499   15500      2012.0                ford f250  excellent        8.0  gas
#
#        odometer transmission   type paint_color  is_4wd date_posted  \
# 42029  107447.0    automatic    SUV        blue     1.0  2018-05-20
# 43880  103767.0    automatic  truck        blue     1.0  2018-11-04
# 18958     128.0    automatic    SUV       black     1.0  2018-05-27
# ...

# %%
#looking for missing values
vehicles.isna()
# Out:
#        price  model_year  model  condition  cylinders   fuel  odometer  \
# 5      False       False  False      False      False  False     False
# 7      False       False  False      False      False  False     False
# 10     False       False  False      False      False  False     False
# 14     False       False  False      False      False  False     False
# 16     False       False  False      False      False  False     False
# ...      ...         ...    ...        ...        ...    ...       ...
# 51494  False       False  False      False      False  False     False
# 51500  False       False  False      False      False  False     False
# 51509  False       False  False      False      False  False     False
# 51513  False       False  False      False      False  False     False
# 51515  False       False  False      False      False  False     False
#
#        transmission   type  paint_color  is_4wd  date_posted  days_listed
# ...

# %%
#Counting missing values
vehicles.isna().sum()
# Out:
# price           0
# model_year      0
# model           0
# condition       0
# cylinders       0
# fuel            0
# odometer        0
# transmission    0
# type            0
# paint_color     0
# is_4wd          0
# date_posted     0
# days_listed     0
# dtype: int64

# %%
#Looking for missing values with value_counts()
display(vehicles.value_counts(dropna=False))
# Out:
# price   model_year  model            condition  cylinders  fuel    odometer  transmission  type    paint_color  is_4wd  date_posted  days_listed
# 1       1997.0      ford f350        good       8.0        diesel  300000.0  automatic     truck   white        1.0     2019-01-22   51             1
# 18490   2015.0      ford f-250 sd    good       8.0        gas     124332.0  automatic     truck   white        1.0     2018-07-23   25             1
# 18400   2005.0      ford f250        good       8.0        diesel  206321.0  automatic     pickup  white        1.0     2018-06-10   53             1
#         2011.0      ram 1500         excellent  8.0        gas     66508.0   automatic     truck   silver       1.0     2018-09-06   31             1
#         2015.0      ram 1500         excellent  8.0        gas     70000.0   automatic     truck   black        1.0     2019-03-06   117            1
# ...

# %%
#Checking for fully duplicated rows
vehicles.duplicated()
# Out:
# 5        False
# 7        False
# 10       False
# 14       False
# 16       False
#          ...
# 51494    False
# 51500    False
# 51509    False
# 51513    False
# 51515    False
# Length: 14852, dtype: bool

# %%
#Counting duplicated rows
vehicles.duplicated().sum()
# Out:
# 0
